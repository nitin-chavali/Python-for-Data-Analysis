# %%
pip install pandas
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 26.0.1 -> 26.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import pandas as pd

# %%
pd.__version__
# Out:
# '2.3.3'

# %%
#1.Create dataframe
df=pd.DataFrame([1,2,3],columns=['Number'])
print(df)
print(type(df))
# Out:
#    Number
# 0       1
# 1       2
# 2       3
# <class 'pandas.core.frame.DataFrame'>

# %%
data={
    'Name':['Nitin','Sagar','Sudip','Omkar'],
    'Age':[25,24,26,23],
    'Salary':[700000,80000,90000,50000]
}

# %%
df=pd.DataFrame(data)
df
# Out:
#     Name  Age  Salary
# 0  Nitin   25  700000
# 1  Sagar   24   80000
# 2  Sudip   26   90000
# 3  Omkar   23   50000

# %%
#2. Basic DataFrame understanding

# %%
df.head(10)
df.tail()
df.shape
df.columns
# Out:
# Index(['Name', 'Age', 'Salary'], dtype='object')

# %%
df.rename(columns={'Salary': 'Monthly_Salary'},inplace=True)

# %%
df
# Out:
#     Name  Age  Monthly_Salary
# 0  Nitin   25          700000
# 1  Sagar   24           80000
# 2  Sudip   26           90000
# 3  Omkar   23           50000

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4 entries, 0 to 3
# Data columns (total 3 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Name            4 non-null      object
#  1   Age             4 non-null      int64
#  2   Monthly_Salary  4 non-null      int64
# dtypes: int64(2), object(1)
# memory usage: 228.0+ bytes

# %%
df.describe()
# Out:
#              Age  Monthly_Salary
# count   4.000000         4.00000
# mean   24.500000    230000.00000
# std     1.290994    313793.98762
# min    23.000000     50000.00000
# 25%    23.750000     72500.00000
# 50%    24.500000     85000.00000
# 75%    25.250000    242500.00000
# max    26.000000    700000.00000

# %%
df
# Out:
#     Name  Age  Monthly_Salary
# 0  Nitin   25          700000
# 1  Sagar   24           80000
# 2  Sudip   26           90000
# 3  Omkar   23           50000

# %%
df.to_csv('Test_data.csv',index=False)

# %%
import os
print(os.getcwd())
# Out:
# C:\Users\nitin

# %%
df_new= pd.read_csv(r"C:\Users\nitin\Test_data.csv")

# %%
df_new
# Out:
#     Name  Age  Monthly_Salary
# 0  Nitin   25          700000
# 1  Sagar   24           80000
# 2  Sudip   26           90000
# 3  Omkar   23           50000

# %%
#select column
#df[['NAME']] single column
df[['Name','Monthly_Salary']]
# Out:
#     Name  Monthly_Salary
# 0  Nitin          700000
# 1  Sagar           80000
# 2  Sudip           90000
# 3  Omkar           50000

# %%
#Select row
df.loc[df.Name=='Nitin']
df.loc[(df.Name=='Nitin') &(df.Monthly_Salary>=50000)]
# Out:
#     Name  Age  Monthly_Salary
# 0  Nitin   25          700000

# %%
df.iloc[0:2]
# Out:
#     Name  Age  Monthly_Salary
# 0  Nitin   25          700000
# 1  Sagar   24           80000

# %%
#Filter DataFrame

# %%
df
# Out:
#     Name  Age  Monthly_Salary
# 0  Nitin   25          700000
# 1  Sagar   24           80000
# 2  Sudip   26           90000
# 3  Omkar   23           50000

# %%
df[df['Age']>24]
# Out:
#     Name  Age  Monthly_Salary
# 0  Nitin   25          700000
# 2  Sudip   26           90000

# %%
df.where(df['Monthly_Salary']>50000, other='Not eligible')
# Out:
#            Name           Age Monthly_Salary
# 0         Nitin            25         700000
# 1         Sagar            24          80000
# 2         Sudip            26          90000
# 3  Not eligible  Not eligible   Not eligible

# %%
# How to add new row and column'
df
# Out:
#     Name  Age  Monthly_Salary
# 0  Nitin   25          700000
# 1  Sagar   24           80000
# 2  Sudip   26           90000
# 3  Omkar   23           50000

# %%
df['Team']=['Data_Analyst','System_Eng','DE','SDE']
df
# Out:
#     Name  Age  Monthly_Salary          Team
# 0  Nitin   25          700000  Data_Analyst
# 1  Sagar   24           80000    System_Eng
# 2  Sudip   26           90000            DE
# 3  Omkar   23           50000           SDE

# %%
#add new row
df.loc[len(df)]=['Vinayak',10,22000,'IT']
df
# Out:
#       Name  Age  Monthly_Salary          Team
# 0    Nitin   25          700000  Data_Analyst
# 1    Sagar   24           80000    System_Eng
# 2    Sudip   26           90000            DE
# 3    Omkar   23           50000           SDE
# 4  Vinayak   10           22000            IT

# %%
len(df)
# Out:
# 5

# %%
#update value

df.loc[0,'Monthly_Salary']=950000
df
# Out:
#       Name  Age  Monthly_Salary          Team
# 0    Nitin   25          950000  Data_Analyst
# 1    Sagar   24           80000    System_Eng
# 2    Sudip   26           90000            DE
# 3    Omkar   23           50000           SDE
# 4  Vinayak   10           22000            IT

# %%
df.loc[df.Name=='Nitin','Monthly_Salary']=450000
df
# Out:
#       Name  Age  Monthly_Salary          Team
# 0    Nitin   25          450000  Data_Analyst
# 1    Sagar   24           80000    System_Eng
# 2    Sudip   26           90000            DE
# 3    Omkar   23           50000           SDE
# 4  Vinayak   10           22000            IT

# %%
#delete value

df=df.drop(df[df.Name=='Vinayak'].index)
df
# Out:
#     Name  Age  Monthly_Salary          Team
# 0  Nitin   25          450000  Data_Analyst
# 1  Sagar   24           80000    System_Eng
# 2  Sudip   26           90000            DE
# 3  Omkar   23           50000           SDE

# %%
df=df.rename(columns={'Monthly_Salary':'Salary'})

# %%
# Working Date and time datatype

# %%
df['DOJ']=['2024-01-13','2024-02-13','2024-03-13','2024-04-13']

# %%
df
# Out:
#     Name  Age  Salary          Team         DOJ
# 0  Nitin   25  450000  Data_Analyst  2024-01-13
# 1  Sagar   24   80000    System_Eng  2024-02-13
# 2  Sudip   26   90000            DE  2024-03-13
# 3  Omkar   23   50000           SDE  2024-04-13

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 4 entries, 0 to 3
# Data columns (total 5 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Name    4 non-null      object
#  1   Age     4 non-null      int64
#  2   Salary  4 non-null      int64
#  3   Team    4 non-null      object
#  4   DOJ     4 non-null      object
# dtypes: int64(2), object(3)
# memory usage: 192.0+ bytes

# %%
df['DOJ'].dtype
# Out:
# dtype('O')

# %%
df1=df

# %%
df1['DOJ2']=['2025-02-11','2025-04-13','2025-03-15','2025-06-13']

# %%
df
# Out:
#     Name  Age  Salary          Team         DOJ        DOJ2
# 0  Nitin   25  450000  Data_Analyst  2024-01-13  2025-02-11
# 1  Sagar   24   80000    System_Eng  2024-02-13  2025-04-13
# 2  Sudip   26   90000            DE  2024-03-13  2025-03-15
# 3  Omkar   23   50000           SDE  2024-04-13  2025-06-13

# %%
df1
# Out:
#     Name  Age  Salary          Team         DOJ        DOJ2
# 0  Nitin   25  450000  Data_Analyst  2024-01-13  2025-02-11
# 1  Sagar   24   80000    System_Eng  2024-02-13  2025-04-13
# 2  Sudip   26   90000            DE  2024-03-13  2025-03-15
# 3  Omkar   23   50000           SDE  2024-04-13  2025-06-13

# %%
df=df.drop('DOJ2',axis=1)

# %%
df
# Out:
#     Name  Age  Salary          Team         DOJ
# 0  Nitin   25  450000  Data_Analyst  2024-01-13
# 1  Sagar   24   80000    System_Eng  2024-02-13
# 2  Sudip   26   90000            DE  2024-03-13
# 3  Omkar   23   50000           SDE  2024-04-13

# %%
df['DOJ']=pd.to_datetime(df['DOJ'])

# %%
df['DOJ'].dt.year
# Out:
# 0    2024
# 1    2024
# 2    2024
# 3    2024
# Name: DOJ, dtype: int32

# %%
df['DOJ'].dt.month
# Out:
# 0    1
# 1    2
# 2    3
# 3    4
# Name: DOJ, dtype: int32

# %%
df['DOJ'].dt.day
# Out:
# 0    13
# 1    13
# 2    13
# 3    13
# Name: DOJ, dtype: int32

# %%
df['DOJ'].dt.day_name()
# Out:
# 0     Saturday
# 1      Tuesday
# 2    Wednesday
# 3     Saturday
# Name: DOJ, dtype: object

# %%
df['Month']=df['DOJ'].dt.month

# %%
df
# Out:
#     Name  Age  Salary          Team        DOJ  Month
# 0  Nitin   25  450000  Data_Analyst 2024-01-13      1
# 1  Sagar   24   80000    System_Eng 2024-02-13      2
# 2  Sudip   26   90000            DE 2024-03-13      3
# 3  Omkar   23   50000           SDE 2024-04-13      4

# %%
# Handling missing value

df.isnull()
# Out:
#     Name    Age  Salary   Team    DOJ  Month
# 0  False  False   False  False  False  False
# 1  False  False   False  False  False  False
# 2  False  False   False  False  False  False
# 3  False  False   False  False  False  False

# %%
import numpy as np

# %%
df.loc[df.Name=='Nitin']= np.nan

# %%
df
# Out:
#     Name   Age   Salary        Team        DOJ  Month
# 0    NaN   NaN      NaN         NaN        NaT    NaN
# 1  Sagar  24.0  80000.0  System_Eng 2024-02-13    2.0
# 2  Sudip  26.0  90000.0          DE 2024-03-13    3.0
# 3  Omkar  23.0  50000.0         SDE 2024-04-13    4.0

# %%
df.isnull().sum()
# Out:
# Name      1
# Age       1
# Salary    1
# Team      1
# DOJ       1
# Month     1
# dtype: int64

# %%
df['Month'] = df['Month'].fillna(0).astype(int)

# %%
#Aggregation and group by

# %%
df['Month'].value_counts()
# Out:
# Month
# 0    1
# 2    1
# 3    1
# 4    1
# Name: count, dtype: int64

# %%
df
# Out:
#     Name   Age   Salary        Team        DOJ  Month
# 0    NaN   NaN      NaN         NaN        NaT      0
# 1  Sagar  24.0  80000.0  System_Eng 2024-02-13      2
# 2  Sudip  26.0  90000.0          DE 2024-03-13      3
# 3  Omkar  23.0  50000.0         SDE 2024-04-13      4

# %%
df['Month'] = df['Month'].astype(int)

# %%
df
# Out:
#     Name   Age   Salary        Team        DOJ  Month
# 0    NaN   NaN      NaN         NaN        NaT      0
# 1  Sagar  24.0  80000.0  System_Eng 2024-02-13      2
# 2  Sudip  26.0  90000.0          DE 2024-03-13      3
# 3  Omkar  23.0  50000.0         SDE 2024-04-13      4

# %%
df[df['Month']==2].value_counts()
# Out:
# Name   Age   Salary   Team        DOJ         Month
# Sagar  24.0  80000.0  System_Eng  2024-02-13  2        1
# Name: count, dtype: int64

# %%
df.groupby('Month')['Salary'].sum()
# Out:
# Month
# 0        0.0
# 2    80000.0
# 3    90000.0
# 4    50000.0
# Name: Salary, dtype: float64

# %%
#concatenate and merge dataframe

# %%
df1=pd.DataFrame({'ID':[1,2,3],'Name':['A','B','C']})

# %%
df1
# Out:
#    ID Name
# 0   1    A
# 1   2    B
# 2   3    C

# %%
df2=pd.DataFrame({'ID':[1,2,2,3],'Score':[22,66,66,55]})

# %%
df2
# Out:
#    ID  Score
# 0   1     22
# 1   2     66
# 2   2     66
# 3   3     55

# %%
pd.concat([df1,df2],axis=0)
# Out:
#    ID Name  Score
# 0   1    A    NaN
# 1   2    B    NaN
# 2   3    C    NaN
# 0   1  NaN   22.0
# 1   2  NaN   66.0
# 2   2  NaN   66.0
# 3   3  NaN   55.0

# %%
pd.concat([df1,df2],axis=1)
# Out:
#     ID Name  ID  Score
# 0  1.0    A   1     22
# 1  2.0    B   2     66
# 2  3.0    C   2     66
# 3  NaN  NaN   3     55

# %%
# Merge Join

# %%
pd.merge(df1,df2,how='inner',on='ID')
# Out:
#    ID Name  Score
# 0   1    A     22
# 1   2    B     66
# 2   2    B     66
# 3   3    C     55

# %%
import pandas as pd

# %%
data=[1,2,3,4,5]
series=pd.Series(data)
print(series)
# Out:
# 0    1
# 1    2
# 2    3
# 3    4
# 4    5
# dtype: int64

# %%
#create a series from dictionary

data={'a':1,'b':2}
series_dict=pd.Series(data)
print(series_dict)
# Out:
# a    1
# b    2
# dtype: int64

# %%
#createing a dataframe from a dictionary

data=[{'Name':'Nitin','Age':25},
      {'Name':'Omakr','Age':25},
{'Name':'Sai','Age':25}]
df=pd.DataFrame(data)
print(df)
# Out:
#     Name  Age
# 0  Nitin   25
# 1  Omakr   25
# 2    Sai   25

# %%
pd.read_csv('sales_data.csv' )
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[14], line 1
# ----> 1 pd.read_csv('sales_data.csv')
#
# File ~\anaconda3\Lib\site-packages\pandas\io\parsers\readers.py:1026, in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, date_format, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options, dtype_backend)
#    1013 kwds_defaults = _refine_defaults_read(
#    1014     dialect,
# ...
